# %%
import numpy as np

from Packomania import Packomania
from DE import DifferentialEvolution
from benchmark import results2np, get_popsize, benchmark
from utils import *


from time import time
from random import seed

# %%
num_points_list=[2, 4, 5, 6, 7, 9]
# num_points_list=[7]
get_popsize_func_A3 = lambda popsize: get_popsize(popsize, m=15)
results_A3 = benchmark(differential_weight=0.3,
                       crossover_prob=0.99,
                       max_evaluations=5e6,
                       get_popsize_func=get_popsize_func_A3,
                       num_points_list=num_points_list,
                       min_pop_variance=1e-10,
                       crossover='std',
                       get_init_bounds_func=get_stricter_bounds,
                       optimum_accuracy=1e-3)
# Out:
# Num points: 2
# RUN #1
# Optimum reached
# 	AVG_OBJ:  1.2013334338073662
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 660
# 	RUN DURATION: 0.011994361877441406s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  1.1277115520000214
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 480
# 	RUN DURATION: 0.007979393005371094s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  1.0336556579488942
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 360
# 	RUN DURATION: 0.004988670349121094s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  1.1458185095443676
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.009973764419555664s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  1.1484647479934984
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 540
# 	RUN DURATION: 0.008977174758911133s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  1.1472453909841263
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 540
# 	RUN DURATION: 0.008977413177490234s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  1.1558347582578334
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.009974241256713867s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  1.105291312997258
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 480
# 	RUN DURATION: 0.007980585098266602s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  1.1738672872760847
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 480
# 	RUN DURATION: 0.00897669792175293s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  1.1224170033962748
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 540
# 	RUN DURATION: 0.008977174758911133s
# Num points: 4
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.9862432175941473
# 	BEST_OBJ: 0.9997048976019525
# 	EVALUATIONS: 7920
# 	RUN DURATION: 0.20348429679870605s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.9792976630388782
# 	BEST_OBJ: 0.9998643763132014
# 	EVALUATIONS: 5880
# 	RUN DURATION: 0.15258240699768066s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.982556337825466
# 	BEST_OBJ: 0.9997844021818783
# 	EVALUATIONS: 6840
# 	RUN DURATION: 0.1755843162536621s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.9197363422623069
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 3720
# 	RUN DURATION: 0.0947580337524414s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.9564188243137722
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 6360
# 	RUN DURATION: 0.16358447074890137s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.9748548040861599
# 	BEST_OBJ: 0.9993545555883306
# 	EVALUATIONS: 6600
# 	RUN DURATION: 0.17156362533569336s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.9806902611522504
# 	BEST_OBJ: 0.9993275834075138
# 	EVALUATIONS: 6960
# 	RUN DURATION: 0.18053841590881348s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.9859703455046347
# 	BEST_OBJ: 0.9997525168977733
# 	EVALUATIONS: 6960
# 	RUN DURATION: 0.17954421043395996s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.9927155781241785
# 	BEST_OBJ: 0.9995276807933795
# 	EVALUATIONS: 8520
# 	RUN DURATION: 0.21944212913513184s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.9763848378168157
# 	BEST_OBJ: 0.9990811998920058
# 	EVALUATIONS: 6120
# 	RUN DURATION: 0.15858244895935059s
# Num points: 5
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.7022981150555901
# 	BEST_OBJ: 0.7061172268864767
# 	EVALUATIONS: 17700
# 	RUN DURATION: 0.5715179443359375s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.7025817442242874
# 	BEST_OBJ: 0.7063375833763478
# 	EVALUATIONS: 27450
# 	RUN DURATION: 0.8817565441131592s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.7005469069795869
# 	BEST_OBJ: 0.7062037039940126
# 	EVALUATIONS: 24000
# 	RUN DURATION: 0.7879962921142578s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.7040253966592567
# 	BEST_OBJ: 0.7061706702831012
# 	EVALUATIONS: 17850
# 	RUN DURATION: 0.567556619644165s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.7020033253557336
# 	BEST_OBJ: 0.7063203859277206
# 	EVALUATIONS: 17400
# 	RUN DURATION: 0.5645644664764404s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.699750328946049
# 	BEST_OBJ: 0.7063120816811941
# 	EVALUATIONS: 25350
# 	RUN DURATION: 0.8268969058990479s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.702261245014773
# 	BEST_OBJ: 0.7069488306759697
# 	EVALUATIONS: 32550
# 	RUN DURATION: 1.0603256225585938s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.6963693508341091
# 	BEST_OBJ: 0.706122299027895
# 	EVALUATIONS: 16650
# 	RUN DURATION: 0.5306556224822998s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.7034892281299636
# 	BEST_OBJ: 0.7062831904041951
# 	EVALUATIONS: 21000
# 	RUN DURATION: 0.6622884273529053s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.703236932324614
# 	BEST_OBJ: 0.7061438066827931
# 	EVALUATIONS: 24900
# 	RUN DURATION: 0.7850039005279541s
# Num points: 6
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.5970790984349661
# 	BEST_OBJ: 0.6000300296915305
# 	EVALUATIONS: 92340
# 	RUN DURATION: 3.5928845405578613s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.5992790710850961
# 	BEST_OBJ: 0.6001114033614193
# 	EVALUATIONS: 58140
# 	RUN DURATION: 2.2193634510040283s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.5975403695220098
# 	BEST_OBJ: 0.5999383018208372
# 	EVALUATIONS: 61920
# 	RUN DURATION: 2.3898937702178955s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.5982302047796492
# 	BEST_OBJ: 0.6000900608511838
# 	EVALUATIONS: 69300
# 	RUN DURATION: 2.701137065887451s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.5982180592692455
# 	BEST_OBJ: 0.5999391377763021
# 	EVALUATIONS: 88920
# 	RUN DURATION: 3.4333033561706543s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.5983229391099945
# 	BEST_OBJ: 0.5999910551753366
# 	EVALUATIONS: 76860
# 	RUN DURATION: 2.9594335556030273s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.5983509183292103
# 	BEST_OBJ: 0.6003106637367469
# 	EVALUATIONS: 118800
# 	RUN DURATION: 4.589329957962036s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.5977857887278871
# 	BEST_OBJ: 0.6000648405106525
# 	EVALUATIONS: 89640
# 	RUN DURATION: 3.4452435970306396s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.5990571891410352
# 	BEST_OBJ: 0.599936260231072
# 	EVALUATIONS: 83340
# 	RUN DURATION: 3.1939003467559814s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.5986391179137172
# 	BEST_OBJ: 0.6001276381996283
# 	EVALUATIONS: 129420
# 	RUN DURATION: 5.012224912643433s
# Num points: 7
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.5336034467592915
# 	BEST_OBJ: 0.535011817335745
# 	EVALUATIONS: 221970
# 	RUN DURATION: 10.06640076637268s
# RUN #2
# Population converged
# Restart
# 	 Evaluations 203910
# Population converged
# Restart
# 	 Evaluations 327390
# Optimum reached
# 	AVG_OBJ:  0.5334580689345885
# 	BEST_OBJ: 0.5349153636706565
# 	EVALUATIONS: 489510
# 	RUN DURATION: 21.95815920829773s
# RUN #3
# Population converged
# Restart
# 	 Evaluations 105630
# Optimum reached
# 	AVG_OBJ:  0.5336326020714449
# 	BEST_OBJ: 0.5349523590074896
# 	EVALUATIONS: 192150
# 	RUN DURATION: 8.60910701751709s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.5336946237149789
# 	BEST_OBJ: 0.5350012064285333
# 	EVALUATIONS: 217560
# 	RUN DURATION: 9.755192041397095s
# RUN #5
# Population converged
# Restart
# 	 Evaluations 84000
# Population converged
# Restart
# 	 Evaluations 260190
# Population converged
# Restart
# 	 Evaluations 372540
# Population converged
# Restart
# 	 Evaluations 635040
# Optimum reached
# 	AVG_OBJ:  0.5341729735337816
# 	BEST_OBJ: 0.5349007972296466
# 	EVALUATIONS: 745080
# 	RUN DURATION: 33.496816635131836s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.5336363748939665
# 	BEST_OBJ: 0.5351930777707491
# 	EVALUATIONS: 228060
# 	RUN DURATION: 10.363643884658813s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.5332512079802517
# 	BEST_OBJ: 0.53500780301676
# 	EVALUATIONS: 159600
# 	RUN DURATION: 7.235599517822266s
# RUN #8
# Population converged
# Restart
# 	 Evaluations 123060
# Optimum reached
# 	AVG_OBJ:  0.5341476854250254
# 	BEST_OBJ: 0.5351859519023267
# 	EVALUATIONS: 247800
# 	RUN DURATION: 11.167600154876709s
# RUN #9
# Population converged
# Restart
# 	 Evaluations 229110
# Optimum reached
# 	AVG_OBJ:  0.5346499421708787
# 	BEST_OBJ: 0.5349249150084974
# 	EVALUATIONS: 391440
# 	RUN DURATION: 17.63515281677246s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.5343376501093426
# 	BEST_OBJ: 0.5349536799151777
# 	EVALUATIONS: 101640
# 	RUN DURATION: 4.562398195266724s
# Num points: 9
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.49780888716783345
# 	BEST_OBJ: 0.49905933135264285
# 	EVALUATIONS: 79920
# 	RUN DURATION: 4.979337692260742s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.49784753943373244
# 	BEST_OBJ: 0.4991042437317127
# 	EVALUATIONS: 80730
# 	RUN DURATION: 5.024226665496826s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.4978388516302779
# 	BEST_OBJ: 0.49914458995867184
# 	EVALUATIONS: 88560
# 	RUN DURATION: 5.501035213470459s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.49824593923512445
# 	BEST_OBJ: 0.4992014518896314
# 	EVALUATIONS: 91530
# 	RUN DURATION: 5.684515953063965s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.4977082115228928
# 	BEST_OBJ: 0.49911765935331404
# 	EVALUATIONS: 74520
# 	RUN DURATION: 4.651171922683716s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.4982081009883501
# 	BEST_OBJ: 0.49906891567527295
# 	EVALUATIONS: 89100
# 	RUN DURATION: 5.531931400299072s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.49798587084338164
# 	BEST_OBJ: 0.4990187167229154
# 	EVALUATIONS: 78840
# 	RUN DURATION: 4.906522750854492s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.49786990800999825
# 	BEST_OBJ: 0.49933257422551597
# 	EVALUATIONS: 84510
# 	RUN DURATION: 5.263614177703857s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.4976083426227521
# 	BEST_OBJ: 0.49903040682648314
# 	EVALUATIONS: 85320
# 	RUN DURATION: 5.3045103549957275s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.4980815587002339
# 	BEST_OBJ: 0.4990617999640855
# 	EVALUATIONS: 80730
# 	RUN DURATION: 5.018238544464111s
# Total time 229.32478880882263s

# %%
save_reliable_results('Benchmark/NBB_improv_A3_bounds.csv', num_points_list, results_A3, x_name='num_points')
save_pickle('Benchmark/NBB_improv_A3_bounds.pickle', results_A3)
# Out:
# Saved object

# %%
num_points_list=[2, 4, 5, 6, 7, 9]
get_popsize_func_A6 = lambda dim: get_popsize(dim, m=30)
results_A6 = benchmark(differential_weight=0.1,
                       crossover_prob=0.85,
                       max_evaluations=5e6,
                       get_popsize_func=get_popsize_func_A6,
                       min_pop_variance=1e-25,
                       crossover='best_points3',
                       get_init_bounds_func=get_stricter_bounds,
                       optimum_accuracy=1e-6)
# Out:
# Num points: 2
# RUN #1
# Optimum reached
# 	AVG_OBJ:  1.2707882853492258
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 2040
# 	RUN DURATION: 0.042884111404418945s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  1.1617100141102905
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1440
# 	RUN DURATION: 0.025930166244506836s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  1.2284675947196753
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1800
# 	RUN DURATION: 0.031914472579956055s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  1.24240167997348
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1920
# 	RUN DURATION: 0.032912492752075195s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  1.1627783919546224
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1560
# 	RUN DURATION: 0.026927947998046875s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  1.2682890080005227
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 2040
# 	RUN DURATION: 0.035904884338378906s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  1.1191482509728214
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1320
# 	RUN DURATION: 0.02393507957458496s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  1.1586624507655163
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1440
# 	RUN DURATION: 0.024933338165283203s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  1.2117447286026752
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1560
# 	RUN DURATION: 0.03191423416137695s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  1.2011203121504426
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1680
# 	RUN DURATION: 0.031914710998535156s
# Num points: 4
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.9999859668778396
# 	BEST_OBJ: 0.9999991841565433
# 	EVALUATIONS: 17520
# 	RUN DURATION: 0.5066444873809814s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.9999420423063673
# 	BEST_OBJ: 0.9999995173979609
# 	EVALUATIONS: 17040
# 	RUN DURATION: 0.49866628646850586s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.9999906492538737
# 	BEST_OBJ: 0.9999997564085975
# 	EVALUATIONS: 16320
# 	RUN DURATION: 0.47971630096435547s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.9999329694999536
# 	BEST_OBJ: 0.9999992887071817
# 	EVALUATIONS: 16320
# 	RUN DURATION: 0.485701322555542s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.9999527912883951
# 	BEST_OBJ: 0.9999993028526826
# 	EVALUATIONS: 16320
# 	RUN DURATION: 0.5375616550445557s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.9999831747244232
# 	BEST_OBJ: 0.9999997655538366
# 	EVALUATIONS: 16800
# 	RUN DURATION: 0.5285868644714355s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.9998368598934959
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 14160
# 	RUN DURATION: 0.4507937431335449s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.9992311672650989
# 	BEST_OBJ: 0.9999992828404712
# 	EVALUATIONS: 14880
# 	RUN DURATION: 0.5415511131286621s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.9999461509365639
# 	BEST_OBJ: 0.9999999888546565
# 	EVALUATIONS: 16320
# 	RUN DURATION: 0.5255942344665527s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.9999938109941585
# 	BEST_OBJ: 0.9999996620351543
# 	EVALUATIONS: 18240
# 	RUN DURATION: 0.6183466911315918s
# Num points: 5
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.707079114872085
# 	BEST_OBJ: 0.7071061193984206
# 	EVALUATIONS: 67800
# 	RUN DURATION: 2.938002109527588s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.7071015064704375
# 	BEST_OBJ: 0.7071059057600264
# 	EVALUATIONS: 57300
# 	RUN DURATION: 2.2953898906707764s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.706979402802755
# 	BEST_OBJ: 0.7071059814793164
# 	EVALUATIONS: 52200
# 	RUN DURATION: 2.0854222774505615s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.7070818932950871
# 	BEST_OBJ: 0.7071057927672263
# 	EVALUATIONS: 51600
# 	RUN DURATION: 2.0469717979431152s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.7070958810312302
# 	BEST_OBJ: 0.7071060242790305
# 	EVALUATIONS: 48600
# 	RUN DURATION: 1.913463830947876s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.7070127493917651
# 	BEST_OBJ: 0.707105828918159
# 	EVALUATIONS: 52500
# 	RUN DURATION: 2.0815658569335938s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.7070765786402123
# 	BEST_OBJ: 0.7071064447970208
# 	EVALUATIONS: 55800
# 	RUN DURATION: 2.2151036262512207s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.706775769723356
# 	BEST_OBJ: 0.7071060486097442
# 	EVALUATIONS: 54600
# 	RUN DURATION: 2.166887044906616s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.7067062991481174
# 	BEST_OBJ: 0.7071059061382365
# 	EVALUATIONS: 57900
# 	RUN DURATION: 2.25467848777771s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.7070997452998334
# 	BEST_OBJ: 0.7071057834917965
# 	EVALUATIONS: 54900
# 	RUN DURATION: 2.131722927093506s
# Num points: 6
# RUN #1
# Population converged
# Restart
# 	 Evaluations 402120
# Population converged
# Restart
# 	 Evaluations 804240
# Population converged
# Restart
# 	 Evaluations 2205000
# Population converged
# Restart
# 	 Evaluations 3191040
# Population converged
# Restart
# 	 Evaluations 4271760
# Maximum number of evaluations
# 	AVG_OBJ:  0.597561797968714
# 	BEST_OBJ: 0.5975644639347222
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 247.7870397567749s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.6009183932846819
# 	BEST_OBJ: 0.6009244001317974
# 	EVALUATIONS: 396720
# 	RUN DURATION: 19.23493504524231s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.6009166333226632
# 	BEST_OBJ: 0.6009242531008995
# 	EVALUATIONS: 370080
# 	RUN DURATION: 18.323110580444336s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.6008834280757727
# 	BEST_OBJ: 0.6009242933501417
# 	EVALUATIONS: 201600
# 	RUN DURATION: 9.015880107879639s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.6008906175285574
# 	BEST_OBJ: 0.6009242131074332
# 	EVALUATIONS: 366840
# 	RUN DURATION: 16.940680980682373s
# RUN #6
# Population converged
# Restart
# 	 Evaluations 418680
# Optimum reached
# 	AVG_OBJ:  0.6008966277581318
# 	BEST_OBJ: 0.6009242650422767
# 	EVALUATIONS: 660240
# 	RUN DURATION: 31.524664402008057s
# RUN #7
# Population converged
# Restart
# 	 Evaluations 751680
# Optimum reached
# 	AVG_OBJ:  0.6007213950435191
# 	BEST_OBJ: 0.6009244515353864
# 	EVALUATIONS: 1062000
# 	RUN DURATION: 49.86659789085388s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.6008596327105198
# 	BEST_OBJ: 0.6009245756543056
# 	EVALUATIONS: 214560
# 	RUN DURATION: 9.680102825164795s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.6009144127145325
# 	BEST_OBJ: 0.6009242531642963
# 	EVALUATIONS: 550440
# 	RUN DURATION: 25.25942587852478s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.60091716738362
# 	BEST_OBJ: 0.6009243009915773
# 	EVALUATIONS: 262440
# 	RUN DURATION: 12.851620435714722s
# Num points: 7
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.5358191419587879
# 	BEST_OBJ: 0.5358974156028147
# 	EVALUATIONS: 282240
# 	RUN DURATION: 18.664068698883057s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.5356203630217553
# 	BEST_OBJ: 0.5358974022847732
# 	EVALUATIONS: 1217580
# 	RUN DURATION: 69.13903903961182s
# RUN #3
# Population converged
# Restart
# 	 Evaluations 644700
# Population converged
# Restart
# 	 Evaluations 2535540
# Population converged
# Restart
# 	 Evaluations 4001340
# Maximum number of evaluations
# 	AVG_OBJ:  0.5358828052876157
# 	BEST_OBJ: 0.5358831220619353
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 281.0082459449768s
# RUN #4
# Population converged
# Restart
# 	 Evaluations 1099980
# Optimum reached
# 	AVG_OBJ:  0.5358167464970094
# 	BEST_OBJ: 0.5358973946839135
# 	EVALUATIONS: 2142000
# 	RUN DURATION: 118.85703372955322s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.5358044433985356
# 	BEST_OBJ: 0.5358973998485975
# 	EVALUATIONS: 1386000
# 	RUN DURATION: 75.3414466381073s
# RUN #6
# Population converged
# Restart
# 	 Evaluations 2060520
# Optimum reached
# 	AVG_OBJ:  0.5355585136393998
# 	BEST_OBJ: 0.5358976102339527
# 	EVALUATIONS: 2872800
# 	RUN DURATION: 155.36337208747864s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.5355035117881082
# 	BEST_OBJ: 0.5358975305514154
# 	EVALUATIONS: 1169280
# 	RUN DURATION: 62.818947076797485s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.5357226843648063
# 	BEST_OBJ: 0.5358974920942866
# 	EVALUATIONS: 1294020
# 	RUN DURATION: 71.80490756034851s
# RUN #9
# Population converged
# Restart
# 	 Evaluations 1046640
# Optimum reached
# 	AVG_OBJ:  0.535806349026225
# 	BEST_OBJ: 0.5358978192177482
# 	EVALUATIONS: 1765260
# 	RUN DURATION: 93.45000267028809s
# RUN #10
# Population converged
# Restart
# 	 Evaluations 688380
# Optimum reached
# 	AVG_OBJ:  0.5356262530438386
# 	BEST_OBJ: 0.5358974516339178
# 	EVALUATIONS: 1394820
# 	RUN DURATION: 74.94351077079773s
# Num points: 9
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.49999752055649305
# 	BEST_OBJ: 0.49999906132349864
# 	EVALUATIONS: 160920
# 	RUN DURATION: 11.638863563537598s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.4999947485162558
# 	BEST_OBJ: 0.4999990253306333
# 	EVALUATIONS: 169560
# 	RUN DURATION: 12.29610562324524s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.499997487527802
# 	BEST_OBJ: 0.49999901432709487
# 	EVALUATIONS: 173340
# 	RUN DURATION: 12.541449308395386s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.49999644346849886
# 	BEST_OBJ: 0.4999990022624329
# 	EVALUATIONS: 153360
# 	RUN DURATION: 11.245915412902832s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.4999968835427029
# 	BEST_OBJ: 0.49999908415190175
# 	EVALUATIONS: 156060
# 	RUN DURATION: 11.508212327957153s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.499996394919168
# 	BEST_OBJ: 0.49999905826751456
# 	EVALUATIONS: 158220
# 	RUN DURATION: 11.880218029022217s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.49999688621485777
# 	BEST_OBJ: 0.4999993338130364
# 	EVALUATIONS: 173340
# 	RUN DURATION: 13.260526418685913s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.49999816149149306
# 	BEST_OBJ: 0.4999991556427021
# 	EVALUATIONS: 193860
# 	RUN DURATION: 14.177072763442993s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.4997416595088107
# 	BEST_OBJ: 0.4999990857301446
# 	EVALUATIONS: 172800
# 	RUN DURATION: 12.568377256393433s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.49983055548491256
# 	BEST_OBJ: 0.4999990563955795
# 	EVALUATIONS: 171180
# 	RUN DURATION: 12.333006858825684s
# Total time 1613.0261895656586s

# %%
save_reliable_results('Benchmark/NBB_improv_A6_full_CR85.csv', num_points_list, results_A6, x_name='num_points')
save_pickle('Benchmark/NBB_improv_A6_full_CR85.pickle', results_A6)
# Out:
# Saved object

# %%
results_A6 = load_pickle('Benchmark/BB_improv_A6.pickle')

# %%
import numpy as np
def results2np(results_A3, results_A6):
    mean_evals_A3 = [np.mean(r['evaluations']) for r in results_A3]
    mean_evals_A6 = [np.mean(r['evaluations']) for r in results_A6]
    return np.array([mean_evals_A3, mean_evals_A6])

# %%
np_results_improv = results2np(results_A3, results_A6)

# %%
np.save('Benchmark/BB_improve', np_results_improv)
