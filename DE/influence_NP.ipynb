# %%
import matplotlib.pyplot as plt
import numpy as np

from math import sqrt
from time import sleep, time
from random import seed


from DE import DifferentialEvolution
from Packomania import Packomania
from utils import *

# %%
seed(0)

num_points = 3
bounds = [[0, 1] for i in range(num_points*2)]
pk = Packomania(num_points)
optimum = pk.points_min_dist

differential_weight = 0.5       
crossover_prob = 0.3
D = num_points*2
popsize_list = [D, 5*D, 10*D, 15*D, 20*D]

max_evaluations = 5e6
optimum_accuracy = 1e-6
results = []


start_time = time()
for popsize in popsize_list:
    print(f"Popsize: {popsize}")
    de = DifferentialEvolution(
                       scattering_points, 
                       bounds, 
                       popsize, 
                       differential_weight, 
                       crossover_prob
    )
    de.set_optimum(optimum, optimum_accuracy)
    failed_flag, r = find_reliable(algo=de, stop_on_fail=False, max_evaluations=max_evaluations, verbose=False)
    results.append(r)
print(f"TOTAL RUNTIME: {time()-start_time}s")
# Out:
# Popsize: 6
# RUN #1
# Population converged
# 	RUN DURATION: 0.13262367248535156s
# RUN #2
# Population converged
# 	RUN DURATION: 0.5703878402709961s
# RUN #3
# Optimum reached
# 	RUN DURATION: 0.18547558784484863s
# RUN #4
# Optimum reached
# 	RUN DURATION: 2.881869077682495s
# RUN #5
# Population converged
# 	RUN DURATION: 0.5474386215209961s
# RUN #6
# Optimum reached
# 	RUN DURATION: 0.06381964683532715s
# RUN #7
# Population converged
# 	RUN DURATION: 0.07279419898986816s
# RUN #8
# Population converged
# 	RUN DURATION: 0.2213749885559082s
# RUN #9
# Population converged
# 	RUN DURATION: 0.33405542373657227s
# RUN #10
# Population converged
# 	RUN DURATION: 3.7005412578582764s
# Popsize: 30
# RUN #1
# Population converged
# 	RUN DURATION: 19.87981390953064s
# RUN #2
# Population converged
# 	RUN DURATION: 17.01291561126709s
# RUN #3
# Optimum reached
# 	RUN DURATION: 14.39232325553894s
# RUN #4
# Population converged
# 	RUN DURATION: 30.320224285125732s
# RUN #5
# Optimum reached
# 	RUN DURATION: 10.860304832458496s
# RUN #6
# Population converged
# 	RUN DURATION: 25.081112384796143s
# RUN #7
# Population converged
# 	RUN DURATION: 54.623615741729736s
# RUN #8
# Population converged
# 	RUN DURATION: 11.74779725074768s
# RUN #9
# Population converged
# 	RUN DURATION: 14.533921957015991s
# RUN #10
# Population converged
# 	RUN DURATION: 17.809664249420166s
# Popsize: 60
# RUN #1
# Population converged
# 	RUN DURATION: 28.51241421699524s
# RUN #2
# Optimum reached
# 	RUN DURATION: 17.422986030578613s
# RUN #3
# Population converged
# 	RUN DURATION: 43.485313415527344s
# RUN #4
# Population converged
# 	RUN DURATION: 36.340274810791016s
# RUN #5
# Optimum reached
# 	RUN DURATION: 35.66470146179199s
# RUN #6
# Population converged
# 	RUN DURATION: 71.60957431793213s
# RUN #7
# Population converged
# 	RUN DURATION: 28.42843532562256s
# RUN #8
# Population converged
# 	RUN DURATION: 65.78787589073181s
# RUN #9
# Population converged
# 	RUN DURATION: 68.47635173797607s
# RUN #10
# Population converged
# 	RUN DURATION: 27.999635696411133s
# Popsize: 90
# RUN #1
# Optimum reached
# 	RUN DURATION: 48.14924240112305s
# RUN #2
# Optimum reached
# 	RUN DURATION: 44.88038992881775s
# RUN #3
# Population converged
# 	RUN DURATION: 71.01524639129639s
# RUN #4
# Population converged
# 	RUN DURATION: 60.097800970077515s
# RUN #5
# Maximum number of evaluations
# 	RUN DURATION: 102.77236557006836s
# RUN #6
# Optimum reached
# 	RUN DURATION: 49.30799865722656s
# RUN #7
# Optimum reached
# 	RUN DURATION: 44.29303479194641s
# RUN #8
# Population converged
# 	RUN DURATION: 98.32840156555176s
# RUN #9
# Optimum reached
# 	RUN DURATION: 30.617175340652466s
# RUN #10
# Population converged
# 	RUN DURATION: 78.4945330619812s
# Popsize: 120
# RUN #1
# Optimum reached
# 	RUN DURATION: 36.276496171951294s
# RUN #2
# Optimum reached
# 	RUN DURATION: 51.27793502807617s
# RUN #3
# Maximum number of evaluations
# 	RUN DURATION: 99.67186188697815s
# RUN #4
# Optimum reached
# 	RUN DURATION: 39.211365699768066s
# RUN #5
# Optimum reached
# 	RUN DURATION: 42.58003306388855s
# RUN #6
# Optimum reached
# 	RUN DURATION: 47.951152324676514s
# RUN #7
# Optimum reached
# 	RUN DURATION: 92.04500031471252s
# RUN #8
# Optimum reached
# 	RUN DURATION: 58.45703840255737s
# RUN #9
# Optimum reached
# 	RUN DURATION: 77.31280589103699s
# RUN #10
# Population converged
# 	RUN DURATION: 83.58243656158447s
# TOTAL RUNTIME: 1905.0478909015656s

# %%
save_reliable_results(f"Params/num_points_{num_points}_{optimum_accuracy}_NP.csv", popsize_list, results)
# Out:
# Exitflag -3, Filtered 6834
# Exitflag -3, Filtered 27996
# Exitflag -3, Filtered 25734
# Exitflag -3, Filtered 3282
# Exitflag -3, Filtered 10146
# Exitflag -3, Filtered 15408
# Exitflag -3, Filtered 165858
# Exitflag -3, Filtered 6834
# Exitflag -3, Filtered 27996
# Exitflag -3, Filtered 25734
# Exitflag -3, Filtered 3282
# Exitflag -3, Filtered 10146
# Exitflag -3, Filtered 15408
# Exitflag -3, Filtered 165858
# Exitflag -3, Filtered 867600
# Exitflag -3, Filtered 756420
# Exitflag -3, Filtered 1548180
# Exitflag -3, Filtered 1362330
# Exitflag -3, Filtered 2990970
# Exitflag -3, Filtered 630990
# Exitflag -3, Filtered 787950
# Exitflag -3, Filtered 981120
# Exitflag -3, Filtered 867600
# Exitflag -3, Filtered 756420
# Exitflag -3, Filtered 1548180
# Exitflag -3, Filtered 1362330
# Exitflag -3, Filtered 2990970
# Exitflag -3, Filtered 630990
# Exitflag -3, Filtered 787950
# Exitflag -3, Filtered 981120
# Exitflag -3, Filtered 1494180
# Exitflag -3, Filtered 2306400
# Exitflag -3, Filtered 1896000
# Exitflag -3, Filtered 3810120
# Exitflag -3, Filtered 1499160
# Exitflag -3, Filtered 3498960
# Exitflag -3, Filtered 3647820
# Exitflag -3, Filtered 1417200
# Exitflag -3, Filtered 1494180
# Exitflag -3, Filtered 2306400
# Exitflag -3, Filtered 1896000
# Exitflag -3, Filtered 3810120
# Exitflag -3, Filtered 1499160
# Exitflag -3, Filtered 3498960
# Exitflag -3, Filtered 3647820
# Exitflag -3, Filtered 1417200
# Exitflag -3, Filtered 3427920
# Exitflag -3, Filtered 2867220
# Exitflag -3, Filtered 4645170
# Exitflag -3, Filtered 3913200
# Exitflag -3, Filtered 3427920
# Exitflag -3, Filtered 2867220
# Exitflag -3, Filtered 4645170
# Exitflag -3, Filtered 3913200
# Exitflag -3, Filtered 4227600
# Exitflag -3, Filtered 4227600

# %%
save_pickle(f"Params/num_points_{num_points}_{optimum_accuracy}_NP.pickle", results)
# Out:
# Saved object
