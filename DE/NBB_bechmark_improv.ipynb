# %%
import numpy as np

from Packomania import Packomania
from DE import DifferentialEvolution
from benchmark import results2np, get_popsize, benchmark
from utils import *


from time import time
from random import seed

# %%
num_points_list=[2, 4, 5, 6, 7, 9]
# num_points_list=[7]
get_popsize_func_A3 = lambda popsize: get_popsize(popsize, m=15)
results_A3 = benchmark(differential_weight=0.3,
                       crossover_prob=0.99,
                       max_evaluations=5e6,
                       get_popsize_func=get_popsize_func_A3,
                       num_points_list=num_points_list,
                       min_pop_variance=1e-10,
                       crossover='best_points3',
#                        get_init_bounds_func=get_stricter_bounds,
                       optimum_accuracy=1e-3)
# Out:
# Num points: 2
# RUN #1
# Optimum reached
# 	AVG_OBJ:  1.0968570759082528
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 480
# 	RUN DURATION: 0.009973526000976562s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  1.2377797016714533
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 720
# 	RUN DURATION: 0.012966394424438477s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  1.1636073795033406
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.010969161987304688s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  1.2064242229132127
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 660
# 	RUN DURATION: 0.011967897415161133s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  1.0351778387043387
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 360
# 	RUN DURATION: 0.005984067916870117s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  1.2047921558543808
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.01098179817199707s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.9961808854192344
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 300
# 	RUN DURATION: 0.003977775573730469s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  1.177003787577006
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 720
# 	RUN DURATION: 0.012965679168701172s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  1.0081843457084532
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 360
# 	RUN DURATION: 0.00498652458190918s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  1.1540622322972487
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 480
# 	RUN DURATION: 0.008976221084594727s
# Num points: 4
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.7117559977011907
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 3360
# 	RUN DURATION: 0.09275102615356445s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.6493846553211935
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 2640
# 	RUN DURATION: 0.07380270957946777s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.6203425308935065
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 2520
# 	RUN DURATION: 0.06682181358337402s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.701796241472548
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 3000
# 	RUN DURATION: 0.08078408241271973s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.7487397664533791
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 3240
# 	RUN DURATION: 0.09075736999511719s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.8100270022916255
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 5160
# 	RUN DURATION: 0.17154145240783691s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.638370735388188
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 3240
# 	RUN DURATION: 0.10372209548950195s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.7109387400948696
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 3120
# 	RUN DURATION: 0.09075784683227539s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.7754935019885225
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 4800
# 	RUN DURATION: 0.13763070106506348s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.7103409564784113
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 3360
# 	RUN DURATION: 0.10372209548950195s
# Num points: 5
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.6929281603255105
# 	BEST_OBJ: 0.7067885778662432
# 	EVALUATIONS: 32100
# 	RUN DURATION: 1.131981372833252s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.6741303371145311
# 	BEST_OBJ: 0.7067141369035316
# 	EVALUATIONS: 22950
# 	RUN DURATION: 0.777909517288208s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.6473076144268324
# 	BEST_OBJ: 0.706444809573821
# 	EVALUATIONS: 21300
# 	RUN DURATION: 0.7350349426269531s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.6715306052242292
# 	BEST_OBJ: 0.7064298507466946
# 	EVALUATIONS: 27750
# 	RUN DURATION: 0.974393367767334s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.6863046859253601
# 	BEST_OBJ: 0.7061704998731315
# 	EVALUATIONS: 44550
# 	RUN DURATION: 1.5997200012207031s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.6759599592403309
# 	BEST_OBJ: 0.7067584979750257
# 	EVALUATIONS: 23100
# 	RUN DURATION: 0.8407516479492188s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.6825622618056324
# 	BEST_OBJ: 0.7063004355882125
# 	EVALUATIONS: 29850
# 	RUN DURATION: 1.0631694793701172s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.6825640596909787
# 	BEST_OBJ: 0.7061849571252358
# 	EVALUATIONS: 37950
# 	RUN DURATION: 1.3244445323944092s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.6867963840046866
# 	BEST_OBJ: 0.7066613796893876
# 	EVALUATIONS: 14700
# 	RUN DURATION: 0.49767518043518066s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.6962189926708747
# 	BEST_OBJ: 0.7065614330384221
# 	EVALUATIONS: 16950
# 	RUN DURATION: 0.5904123783111572s
# Num points: 6
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.5985229187493015
# 	BEST_OBJ: 0.6000178612709646
# 	EVALUATIONS: 144540
# 	RUN DURATION: 6.207394599914551s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.5963861240962318
# 	BEST_OBJ: 0.6000199453922187
# 	EVALUATIONS: 152100
# 	RUN DURATION: 6.54449200630188s
# RUN #3
# Population converged
# Restart
# 	 Evaluations 147060
# Population converged
# Restart
# 	 Evaluations 493740
# Optimum reached
# 	AVG_OBJ:  0.5989177080051242
# 	BEST_OBJ: 0.5999667812229443
# 	EVALUATIONS: 756180
# 	RUN DURATION: 31.66528868675232s
# RUN #4
# Population converged
# Restart
# 	 Evaluations 257040
# Optimum reached
# 	AVG_OBJ:  0.5977357045457923
# 	BEST_OBJ: 0.5999665790435804
# 	EVALUATIONS: 380700
# 	RUN DURATION: 15.479589462280273s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.5979732198075893
# 	BEST_OBJ: 0.600005006736124
# 	EVALUATIONS: 110520
# 	RUN DURATION: 4.5139241218566895s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.5985038023365541
# 	BEST_OBJ: 0.6000726380707697
# 	EVALUATIONS: 255600
# 	RUN DURATION: 10.51988434791565s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.5981247783018525
# 	BEST_OBJ: 0.6000571340755411
# 	EVALUATIONS: 164520
# 	RUN DURATION: 6.841691732406616s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.5977344174940381
# 	BEST_OBJ: 0.6002327085008382
# 	EVALUATIONS: 158580
# 	RUN DURATION: 6.566411972045898s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.597462534684907
# 	BEST_OBJ: 0.6003361857042412
# 	EVALUATIONS: 160560
# 	RUN DURATION: 6.621286630630493s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.5983172057138025
# 	BEST_OBJ: 0.5999884023948913
# 	EVALUATIONS: 100980
# 	RUN DURATION: 4.1219727993011475s
# Num points: 7
# RUN #1
# Population converged
# Restart
# 	 Evaluations 760200
# Optimum reached
# 	AVG_OBJ:  0.5339195694845703
# 	BEST_OBJ: 0.5350301138962165
# 	EVALUATIONS: 1823850
# 	RUN DURATION: 88.22498106956482s
# RUN #2
# Population converged
# Restart
# 	 Evaluations 1442910
# Optimum reached
# 	AVG_OBJ:  0.5322854567712697
# 	BEST_OBJ: 0.5350716267657762
# 	EVALUATIONS: 2284800
# 	RUN DURATION: 111.76101636886597s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.5314509178525559
# 	BEST_OBJ: 0.5349596672135956
# 	EVALUATIONS: 261660
# 	RUN DURATION: 12.56139612197876s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.531626582391707
# 	BEST_OBJ: 0.5349308843033489
# 	EVALUATIONS: 1259370
# 	RUN DURATION: 61.01477289199829s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.5325147735350384
# 	BEST_OBJ: 0.5350118458321157
# 	EVALUATIONS: 1350510
# 	RUN DURATION: 65.04798412322998s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.5338539193502719
# 	BEST_OBJ: 0.5349066997689119
# 	EVALUATIONS: 467880
# 	RUN DURATION: 22.482853651046753s
# RUN #7
# Population converged
# Restart
# 	 Evaluations 334320
# Population converged
# Restart
# 	 Evaluations 824880
# Optimum reached
# 	AVG_OBJ:  0.5332886606589325
# 	BEST_OBJ: 0.534927516743356
# 	EVALUATIONS: 1223040
# 	RUN DURATION: 58.661070108413696s
# RUN #8
# Population converged
# Restart
# 	 Evaluations 605430
# Optimum reached
# 	AVG_OBJ:  0.5337789376320795
# 	BEST_OBJ: 0.5351332369043988
# 	EVALUATIONS: 972510
# 	RUN DURATION: 46.561439514160156s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.5325668260358245
# 	BEST_OBJ: 0.5349345020923328
# 	EVALUATIONS: 801150
# 	RUN DURATION: 39.127325773239136s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.5335982489116177
# 	BEST_OBJ: 0.5350108952097686
# 	EVALUATIONS: 611520
# 	RUN DURATION: 29.48811364173889s
# Num points: 9
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.4952586388975999
# 	BEST_OBJ: 0.499080648244086
# 	EVALUATIONS: 1910520
# 	RUN DURATION: 133.86887407302856s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.497637210310359
# 	BEST_OBJ: 0.49921257869470004
# 	EVALUATIONS: 1991250
# 	RUN DURATION: 137.74051642417908s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.49673818424569277
# 	BEST_OBJ: 0.4990810546843741
# 	EVALUATIONS: 2822040
# 	RUN DURATION: 199.53819513320923s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.4968982644436489
# 	BEST_OBJ: 0.49907393147551504
# 	EVALUATIONS: 1289520
# 	RUN DURATION: 88.04645872116089s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.4975323679272761
# 	BEST_OBJ: 0.4990101653659299
# 	EVALUATIONS: 1735830
# 	RUN DURATION: 118.16787672042847s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.49666241819717577
# 	BEST_OBJ: 0.4990769051101301
# 	EVALUATIONS: 2181330
# 	RUN DURATION: 150.04759287834167s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.4968116528490398
# 	BEST_OBJ: 0.4990782759998484
# 	EVALUATIONS: 2770470
# 	RUN DURATION: 193.28293013572693s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.4943941910744842
# 	BEST_OBJ: 0.49905429609134827
# 	EVALUATIONS: 1931040
# 	RUN DURATION: 132.21031141281128s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.49762025029358115
# 	BEST_OBJ: 0.499029970411593
# 	EVALUATIONS: 2881440
# 	RUN DURATION: 196.63695693016052s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.49585046978980735
# 	BEST_OBJ: 0.49900694876153123
# 	EVALUATIONS: 2031480
# 	RUN DURATION: 140.01144123077393s
# Total time 2134.2544424533844s

# %%
save_reliable_results('Benchmark/NBB_improv_A3_bp.csv', num_points_list, results_A3, x_name='num_points')
save_pickle('Benchmark/NBB_improv_A3_bp.pickle', results_A3)
# Out:
# Saved object

# %%
num_points_list=[2, 4, 5, 6, 7, 9]
get_popsize_func_A6 = lambda dim: get_popsize(dim, m=30)
results_A6 = benchmark(differential_weight=0.1,
                       crossover_prob=0.9,
                       max_evaluations=5e6,
                       get_popsize_func=get_popsize_func_A6,
                       min_pop_variance=1e-25,
                       crossover='best_points3',
#                        get_init_bounds_func=get_stricter_bounds,
                       optimum_accuracy=1e-6)
# Out:
# Num points: 2
# RUN #1
# Optimum reached
# 	AVG_OBJ:  1.1169784108375975
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1320
# 	RUN DURATION: 0.025935888290405273s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  1.1809185250348622
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1440
# 	RUN DURATION: 0.0259244441986084s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  1.2330742143728346
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1440
# 	RUN DURATION: 0.02593088150024414s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  1.2108914205529688
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1560
# 	RUN DURATION: 0.027925729751586914s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  1.2280589461930715
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1680
# 	RUN DURATION: 0.028922080993652344s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  1.2326192064957269
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1560
# 	RUN DURATION: 0.0269317626953125s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  1.1308663035768327
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1200
# 	RUN DURATION: 0.0199432373046875s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  1.233322857434878
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1680
# 	RUN DURATION: 0.029920101165771484s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  1.2055213779526537
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1560
# 	RUN DURATION: 0.028922557830810547s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  1.211508846062828
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 1440
# 	RUN DURATION: 0.027924776077270508s
# Num points: 4
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.7918722550832624
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 9360
# 	RUN DURATION: 0.2682826519012451s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.8806640692534506
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 12960
# 	RUN DURATION: 0.3899567127227783s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.8351072885113484
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 10560
# 	RUN DURATION: 0.32213902473449707s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.8430972857993687
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 12240
# 	RUN DURATION: 0.3530547618865967s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.830646242392339
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 10320
# 	RUN DURATION: 0.29024481773376465s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.820939986199027
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 10080
# 	RUN DURATION: 0.2882072925567627s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.9115542486238842
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 15840
# 	RUN DURATION: 0.4527881145477295s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.8728118245392349
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 12720
# 	RUN DURATION: 0.39294886589050293s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.7842628646662455
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 8640
# 	RUN DURATION: 0.25733327865600586s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.8074750663951884
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 10320
# 	RUN DURATION: 0.3022024631500244s
# Num points: 5
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.7068933230910415
# 	BEST_OBJ: 0.7071059461346447
# 	EVALUATIONS: 105000
# 	RUN DURATION: 4.103985071182251s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.7054313736567877
# 	BEST_OBJ: 0.707106303168066
# 	EVALUATIONS: 57000
# 	RUN DURATION: 2.1991162300109863s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.7060774442598936
# 	BEST_OBJ: 0.7071058707329088
# 	EVALUATIONS: 89100
# 	RUN DURATION: 3.3251254558563232s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.7055245210038547
# 	BEST_OBJ: 0.7071058019927197
# 	EVALUATIONS: 58500
# 	RUN DURATION: 2.1990959644317627s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.707013598324345
# 	BEST_OBJ: 0.7071058672733834
# 	EVALUATIONS: 105600
# 	RUN DURATION: 3.945446014404297s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.7059093193593339
# 	BEST_OBJ: 0.7071058740186636
# 	EVALUATIONS: 77400
# 	RUN DURATION: 2.897249221801758s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.7050887969623596
# 	BEST_OBJ: 0.707105864430715
# 	EVALUATIONS: 62700
# 	RUN DURATION: 2.334754228591919s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.7054105715807405
# 	BEST_OBJ: 0.7071062387181943
# 	EVALUATIONS: 78000
# 	RUN DURATION: 2.9481122493743896s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.7060827845546803
# 	BEST_OBJ: 0.7071061362455794
# 	EVALUATIONS: 51600
# 	RUN DURATION: 1.9318675994873047s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.7068110390977048
# 	BEST_OBJ: 0.7071062396860253
# 	EVALUATIONS: 70800
# 	RUN DURATION: 2.7236783504486084s
# Num points: 6
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.6008660702898586
# 	BEST_OBJ: 0.600924600994385
# 	EVALUATIONS: 377280
# 	RUN DURATION: 17.300718784332275s
# RUN #2
# Population converged
# Restart
# 	 Evaluations 728280
# Population converged
# Restart
# 	 Evaluations 1587960
# Optimum reached
# 	AVG_OBJ:  0.6009223752223284
# 	BEST_OBJ: 0.6009243137739962
# 	EVALUATIONS: 2065320
# 	RUN DURATION: 93.77014493942261s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.6009218319530403
# 	BEST_OBJ: 0.6009244933520979
# 	EVALUATIONS: 410760
# 	RUN DURATION: 18.11553692817688s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.6008728349856954
# 	BEST_OBJ: 0.6009244658236615
# 	EVALUATIONS: 402840
# 	RUN DURATION: 18.4037663936615s
# RUN #5
# Population converged
# Restart
# 	 Evaluations 639720
# Population converged
# Restart
# 	 Evaluations 1200960
# Optimum reached
# 	AVG_OBJ:  0.6009218592897896
# 	BEST_OBJ: 0.6009243293445485
# 	EVALUATIONS: 1469160
# 	RUN DURATION: 64.23715257644653s
# RUN #6
# Population converged
# Restart
# 	 Evaluations 1334160
# Population converged
# Restart
# 	 Evaluations 1820880
# Optimum reached
# 	AVG_OBJ:  0.6009219986192131
# 	BEST_OBJ: 0.6009242494166149
# 	EVALUATIONS: 2120400
# 	RUN DURATION: 92.33698344230652s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.6009219142938367
# 	BEST_OBJ: 0.6009243079854077
# 	EVALUATIONS: 430920
# 	RUN DURATION: 18.732892990112305s
# RUN #8
# Population converged
# Restart
# 	 Evaluations 1624680
# Population converged
# Restart
# 	 Evaluations 2035800
# Optimum reached
# 	AVG_OBJ:  0.6009162456430415
# 	BEST_OBJ: 0.6009245311634507
# 	EVALUATIONS: 2247120
# 	RUN DURATION: 94.9429976940155s
# RUN #9
# Population converged
# Restart
# 	 Evaluations 338400
# Optimum reached
# 	AVG_OBJ:  0.600921274880337
# 	BEST_OBJ: 0.600924232860433
# 	EVALUATIONS: 866520
# 	RUN DURATION: 37.38199591636658s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.6009170254792549
# 	BEST_OBJ: 0.6009242183453416
# 	EVALUATIONS: 334800
# 	RUN DURATION: 14.388508081436157s
# Num points: 7
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.5358914407070402
# 	BEST_OBJ: 0.53589739136018
# 	EVALUATIONS: 548520
# 	RUN DURATION: 27.802600622177124s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.5358970282536938
# 	BEST_OBJ: 0.5358974412676831
# 	EVALUATIONS: 946680
# 	RUN DURATION: 49.41480588912964s
# RUN #3
# Population converged
# Restart
# 	 Evaluations 1220520
# Optimum reached
# 	AVG_OBJ:  0.5354700760499335
# 	BEST_OBJ: 0.5358973989048387
# 	EVALUATIONS: 1818180
# 	RUN DURATION: 94.56103038787842s
# RUN #4
# Population converged
# Restart
# 	 Evaluations 1480080
# Optimum reached
# 	AVG_OBJ:  0.5358923283640958
# 	BEST_OBJ: 0.5358974594359427
# 	EVALUATIONS: 2491860
# 	RUN DURATION: 131.2778058052063s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.5358966415212788
# 	BEST_OBJ: 0.5358974193635854
# 	EVALUATIONS: 455280
# 	RUN DURATION: 23.2238712310791s
# RUN #6
# Population converged
# Restart
# 	 Evaluations 2877840
# Population converged
# Restart
# 	 Evaluations 3296160
# Population converged
# Restart
# 	 Evaluations 4090800
# Maximum number of evaluations
# 	AVG_OBJ:  0.52127173239726
# 	BEST_OBJ: 0.5300370018898655
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 257.0553255081177s
# RUN #7
# Population converged
# Restart
# 	 Evaluations 297780
# Population converged
# Restart
# 	 Evaluations 1293600
# Optimum reached
# 	AVG_OBJ:  0.535893083829375
# 	BEST_OBJ: 0.5358974523407777
# 	EVALUATIONS: 2735460
# 	RUN DURATION: 145.98845195770264s
# RUN #8
# Population converged
# Restart
# 	 Evaluations 590940
# Optimum reached
# 	AVG_OBJ:  0.5358289202540258
# 	BEST_OBJ: 0.5358973858989283
# 	EVALUATIONS: 1316700
# 	RUN DURATION: 67.82954287528992s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.535896011557065
# 	BEST_OBJ: 0.5358975271852475
# 	EVALUATIONS: 695100
# 	RUN DURATION: 35.953815937042236s
# RUN #10
# Population converged
# Restart
# 	 Evaluations 1864380
# Population converged
# Restart
# 	 Evaluations 4701060
# Maximum number of evaluations
# 	AVG_OBJ:  0.4890578223440686
# 	BEST_OBJ: 0.5150160430955435
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 259.6124846935272s
# Num points: 9
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.49789617195673813
# 	BEST_OBJ: 0.4999990673288568
# 	EVALUATIONS: 3588300
# 	RUN DURATION: 259.6752905845642s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.4960111096545702
# 	BEST_OBJ: 0.4999990320421605
# 	EVALUATIONS: 1050300
# 	RUN DURATION: 74.95755696296692s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.49868960601091683
# 	BEST_OBJ: 0.49999905555677354
# 	EVALUATIONS: 2351160
# 	RUN DURATION: 169.37089920043945s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.49620170877801095
# 	BEST_OBJ: 0.49999923339840185
# 	EVALUATIONS: 1152900
# 	RUN DURATION: 82.19112277030945s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.4972803223906052
# 	BEST_OBJ: 0.49999904370399256
# 	EVALUATIONS: 1509840
# 	RUN DURATION: 108.13382482528687s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.4968829089570376
# 	BEST_OBJ: 0.4999990560772793
# 	EVALUATIONS: 1071360
# 	RUN DURATION: 76.28996706008911s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.49954816911070665
# 	BEST_OBJ: 0.4999990425373871
# 	EVALUATIONS: 3423600
# 	RUN DURATION: 246.49065399169922s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.4991663797514297
# 	BEST_OBJ: 0.4999991340783372
# 	EVALUATIONS: 2380860
# 	RUN DURATION: 171.70574522018433s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.49457886976734305
# 	BEST_OBJ: 0.4999990236611202
# 	EVALUATIONS: 879120
# 	RUN DURATION: 62.18963599205017s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.4979301770371935
# 	BEST_OBJ: 0.49999905653153764
# 	EVALUATIONS: 1380780
# 	RUN DURATION: 98.42880082130432s
# Total time 2944.036635875702s

# %%
save_reliable_results('Benchmark/NBB_improv_A6_bp.csv', num_points_list, results_A6, x_name='num_points')
save_pickle('Benchmark/NBB_improv_A6_bp.pickle', results_A6)
# Out:
# Saved object

# %%
results_A6 = load_pickle('Benchmark/BB_improv_A6.pickle')

# %%
import numpy as np
def results2np(results_A3, results_A6):
    mean_evals_A3 = [np.mean(r['evaluations']) for r in results_A3]
    mean_evals_A6 = [np.mean(r['evaluations']) for r in results_A6]
    return np.array([mean_evals_A3, mean_evals_A6])

# %%
np_results_improv = results2np(results_A3, results_A6)

# %%
np.save('Benchmark/BB_improve', np_results_improv)
