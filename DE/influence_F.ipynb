# %%
import matplotlib.pyplot as plt
import numpy as np

from math import sqrt
from time import sleep, time
from random import seed


from DE import DifferentialEvolution
from Packomania import Packomania
from utils import *

# %%
seed(0)

num_points = 9
bounds = [[0, 1] for i in range(num_points*2)]
pk = Packomania(num_points)
optimum = pk.points_min_dist

differential_weight_list = [0.1, 0.3, 0.5, 0.8, 1.0]         
crossover_prob = 0.3
popsize = 10*num_points*2 # *2 since dimension is num_points*2

max_evaluations = 5e6
optimum_accuracy = 1e-3
results = []


start_time = time()
for differential_weight in differential_weight_list:
    print(f"Differential_weight: {differential_weight}")
    de = DifferentialEvolution(
                       scattering_points, 
                       bounds, 
                       popsize, 
                       differential_weight, 
                       crossover_prob
    )
    de.set_optimum(optimum, optimum_accuracy)
    failed_flag, r = find_reliable(algo=de, stop_on_fail=False, max_evaluations=max_evaluations, verbose=False)
    results.append(r)
print(f"TOTAL RUNTIME: {time()-start_time}s")
# Out:
# Differential_weight: 0.1
# RUN #1
# Maximum number of evaluations
# 	RUN DURATION: 328.8624722957611s
# RUN #2
# Maximum number of evaluations
# 	RUN DURATION: 328.24179577827454s
# RUN #3
# Maximum number of evaluations
# 	RUN DURATION: 334.4139542579651s
# RUN #4
# Maximum number of evaluations
# 	RUN DURATION: 328.27065348625183s
# RUN #5
# Maximum number of evaluations
# 	RUN DURATION: 327.80439496040344s
# RUN #6
# Maximum number of evaluations
# 	RUN DURATION: 328.9497981071472s
# RUN #7
# Maximum number of evaluations
# 	RUN DURATION: 327.7300989627838s
# RUN #8
# Maximum number of evaluations
# 	RUN DURATION: 329.0764558315277s
# RUN #9
# Maximum number of evaluations
# 	RUN DURATION: 328.9936797618866s
# RUN #10
# Maximum number of evaluations
# 	RUN DURATION: 327.85376477241516s
# Differential_weight: 0.3
# RUN #1
# Maximum number of evaluations
# 	RUN DURATION: 332.0223197937012s
# RUN #2
# Maximum number of evaluations
# 	RUN DURATION: 332.0830795764923s
# RUN #3
# Maximum number of evaluations
# 	RUN DURATION: 332.24464535713196s
# RUN #4
# Maximum number of evaluations
# 	RUN DURATION: 331.40191102027893s
# RUN #5
# Maximum number of evaluations
# 	RUN DURATION: 331.4258465766907s
# RUN #6
# Maximum number of evaluations
# 	RUN DURATION: 331.0917453765869s
# RUN #7
# Maximum number of evaluations
# 	RUN DURATION: 332.55580854415894s
# RUN #8
# Maximum number of evaluations
# 	RUN DURATION: 331.2706549167633s
# RUN #9
# Maximum number of evaluations
# 	RUN DURATION: 331.33854055404663s
# RUN #10
# Maximum number of evaluations
# 	RUN DURATION: 332.2002294063568s
# Differential_weight: 0.5
# RUN #1
# Optimum reached
# 	RUN DURATION: 160.7300136089325s
# RUN #2
# Optimum reached
# 	RUN DURATION: 87.25603032112122s
# RUN #3
# Optimum reached
# 	RUN DURATION: 147.16438841819763s
# RUN #4
# Optimum reached
# 	RUN DURATION: 115.2898588180542s
# RUN #5
# Optimum reached
# 	RUN DURATION: 105.74046468734741s
# RUN #6
# Optimum reached
# 	RUN DURATION: 115.12131071090698s
# RUN #7
# Optimum reached
# 	RUN DURATION: 154.15265083312988s
# RUN #8
# Optimum reached
# 	RUN DURATION: 181.42354154586792s
# RUN #9
# Optimum reached
# 	RUN DURATION: 82.45118641853333s
# RUN #10
# Optimum reached
# 	RUN DURATION: 95.79743814468384s
# Differential_weight: 0.8
# RUN #1
# Maximum number of evaluations
# 	RUN DURATION: 331.5899636745453s
# RUN #2
# Maximum number of evaluations
# 	RUN DURATION: 332.01083540916443s
# RUN #3
# Maximum number of evaluations
# 	RUN DURATION: 329.5055458545685s
# RUN #4
# Maximum number of evaluations
# 	RUN DURATION: 333.2495176792145s
# RUN #5
# Maximum number of evaluations
# 	RUN DURATION: 330.5198292732239s
# RUN #6
# Maximum number of evaluations
# 	RUN DURATION: 326.66031980514526s
# RUN #7
# Maximum number of evaluations
# 	RUN DURATION: 332.536860704422s
# RUN #8
# Maximum number of evaluations
# 	RUN DURATION: 337.038809299469s
# RUN #9
# Maximum number of evaluations
# 	RUN DURATION: 322.02499890327454s
# RUN #10
# Maximum number of evaluations
# 	RUN DURATION: 322.6313762664795s
# Differential_weight: 1.0
# RUN #1
# Maximum number of evaluations
# 	RUN DURATION: 321.9013295173645s
# RUN #2
# Maximum number of evaluations
# 	RUN DURATION: 322.86475110054016s
# RUN #3
# Maximum number of evaluations
# 	RUN DURATION: 321.7836449146271s
# RUN #4
# Maximum number of evaluations
# 	RUN DURATION: 322.69420742988586s
# RUN #5
# Maximum number of evaluations
# 	RUN DURATION: 323.2237899303436s
# RUN #6
# Maximum number of evaluations
# 	RUN DURATION: 322.7570390701294s
# RUN #7
# Maximum number of evaluations
# 	RUN DURATION: 322.47788643836975s
# RUN #8
# Maximum number of evaluations
# 	RUN DURATION: 322.51304841041565s
# RUN #9
# Maximum number of evaluations
# 	RUN DURATION: 322.4003496170044s
# RUN #10
# Maximum number of evaluations
# 	RUN DURATION: 323.2061936855316s
# TOTAL RUNTIME: 14376.603886842728s

# %%
save_reliable_results(f"Params/num_points_{num_points}_{optimum_accuracy}_F.csv", differential_weight_list, results)

# %%
save_pickle(f"Params/num_points_{num_points}_{optimum_accuracy}_F.pickle", results)
# Out:
# Saved object
