# %%
import numpy as np

from Packomania import Packomania
from DE import DifferentialEvolution
from benchmark import results2np, get_popsize, benchmark
from utils import *

from time import time
from random import seed

# %%
num_points_list=[2, 4, 5, 6, 7, 9]
get_popsize_func_A3 = lambda popsize: get_popsize(popsize, m=10)
results_A3 = benchmark(differential_weight=0.5,
                       crossover_prob=0.3,
                       max_evaluations=5e6,
                       get_popsize_func=get_popsize_func_A3,
                       num_points_list=num_points_list,
                       min_pop_variance=1e-10,
                       optimum_accuracy=1e-3)
# Out:
# Num points: 2
# RUN #1
# Optimum reached
# 	AVG_OBJ:  1.1195623998382878
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.010969877243041992s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  1.1266768930576725
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 640
# 	RUN DURATION: 0.010970354080200195s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  1.142313389011121
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.010970830917358398s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  1.0092882809582264
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 360
# 	RUN DURATION: 0.0059850215911865234s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  1.1689378761503306
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 520
# 	RUN DURATION: 0.009973764419555664s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  1.1065171040770043
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 520
# 	RUN DURATION: 0.009972810745239258s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  1.1426890297178411
# ...

# %%
save_reliable_results('Benchmark/BB_A3_v2.csv', num_points_list, results_A3, x_name='num_points')
save_pickle('Benchmark/DE_BB_A3_v2.pickle', results_A3)
# Out:
# Saved object

# %%
# Accuracy 1e-6
num_points_list=[2, 4, 5, 6, 7, 9]
get_popsize_func_A6 = lambda popsize: get_popsize(popsize, m=10)
results_A6 = benchmark(differential_weight=0.5,
                       crossover_prob=0.3,
                       max_evaluations=5e6,
                       get_popsize_func=get_popsize_func_A6,
                       num_points_list=num_points_list,
                       min_pop_variance=1e-25,
                       optimum_accuracy=1e-6)
# Out:
# Num points: 2
# RUN #1
# Optimum reached
# 	AVG_OBJ:  1.1195623998382878
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.012964010238647461s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  1.1266768930576725
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 640
# 	RUN DURATION: 0.011968135833740234s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  1.142313389011121
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.01096963882446289s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  1.0092882809582264
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 360
# 	RUN DURATION: 0.005983114242553711s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  1.1689378761503306
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 520
# 	RUN DURATION: 0.007978439331054688s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  1.1065171040770043
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 520
# 	RUN DURATION: 0.00897669792175293s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  1.1426890297178411
# ...

# %%
save_reliable_results('Benchmark/BB_A6.csv', num_points_list, results_A6, x_name='num_points')
save_pickle('Benchmark/DE_BB_A6.pickle', results_A6)
# Out:
# Saved object

# %%
# To numpy 
np_results = results2np(results_A3, results_A6)
np.save('Benchmark/DE_BB.pickle', np_results)
