# %%
import matplotlib.pyplot as plt
from math import sqrt
from time import sleep, time
from random import seed

from DE import DifferentialEvolution
from Packomania import Packomania
from utils import *

# %%
seed(0)
num_points_list = [2,3,4,5,6,7,8,9]
differential_weight = 0.5               
crossover_prob = 0.3
max_evaluations = 5e6
optimum_accuracy = 1e-6


results = []
for num_points in num_points_list:
    print("Num points: {}".format(num_points))
    dim = num_points*2
    
    popsize = 10*dim
    bounds = [[0, 1] for i in range(num_points*2)]
    pk = Packomania(num_points)
    optimum = pk.distance
    
    de = DifferentialEvolution(
                       scattering_points, 
                       bounds, 
                       popsize, 
                       differential_weight, 
                       crossover_prob
    )
    de.set_optimum(optimum, optimum_accuracy)
    failed, r = find_reliable(algo=de,
                            stop_on_fail=False,
                            max_evaluations=max_evaluations)
    results.append(r)
    if not failed:
        print("Num_points: {} Solved Reliable".format(num_points) )
# Out:
# Num points: 2
# RUN #1
# Optimum reached
# 	AVG_OBJ:  1.1195623998382878
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.009971857070922852s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  1.1266768930576725
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 640
# 	RUN DURATION: 0.009973764419555664s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  1.142313389011121
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.008975982666015625s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  1.0092882809582264
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 360
# 	RUN DURATION: 0.004986763000488281s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  1.1689378761503306
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 520
# 	RUN DURATION: 0.00698089599609375s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  1.1065171040770043
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 520
# 	RUN DURATION: 0.007978200912475586s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  1.1426890297178411
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 520
# 	RUN DURATION: 0.008975982666015625s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  1.0296873122418526
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 320
# 	RUN DURATION: 0.00498652458190918s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  1.2427433660365765
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 760
# 	RUN DURATION: 0.0109710693359375s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  1.1707435788086424
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.008975744247436523s
# Num_points: 2 Solved Reliable
# Num points: 3
# RUN #1
# Population converged
# 	AVG_OBJ:  1.0351802858176673
# 	BEST_OBJ: 1.0351802858176686
# 	EVALUATIONS: 1945740
# 	RUN DURATION: 37.496755599975586s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  1.0342097878781726
# 	BEST_OBJ: 1.0352753003278017
# 	EVALUATIONS: 2518680
# 	RUN DURATION: 48.44847631454468s
# RUN #3
# Population converged
# 	AVG_OBJ:  1.035250474909006
# 	BEST_OBJ: 1.035250474909006
# 	EVALUATIONS: 2797560
# 	RUN DURATION: 52.808820486068726s
# RUN #4
# Population converged
# 	AVG_OBJ:  1.0351720209525879
# 	BEST_OBJ: 1.0351720209525888
# 	EVALUATIONS: 2556300
# 	RUN DURATION: 48.82447171211243s
# RUN #5
# Population converged
# 	AVG_OBJ:  1.0352630395468
# 	BEST_OBJ: 1.0352630395468014
# 	EVALUATIONS: 3776940
# 	RUN DURATION: 71.77112579345703s
# RUN #6
# Population converged
# 	AVG_OBJ:  1.0350128013815607
# 	BEST_OBJ: 1.0350128013815596
# 	EVALUATIONS: 2480580
# 	RUN DURATION: 46.89762306213379s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  1.0329339609289288
# 	BEST_OBJ: 1.0352756871770783
# 	EVALUATIONS: 903420
# 	RUN DURATION: 17.431398630142212s
# RUN #8
# Population converged
# 	AVG_OBJ:  1.0352532628299698
# 	BEST_OBJ: 1.0352532628299707
# 	EVALUATIONS: 3434460
# 	RUN DURATION: 65.30640864372253s
# RUN #9
# Population converged
# 	AVG_OBJ:  1.035274855180411
# 	BEST_OBJ: 1.035274855180411
# 	EVALUATIONS: 2566620
# 	RUN DURATION: 48.46742582321167s
# RUN #10
# Population converged
# 	AVG_OBJ:  1.0352743930312243
# 	BEST_OBJ: 1.0352743930312251
# 	EVALUATIONS: 2216400
# 	RUN DURATION: 42.04760217666626s
# Num points: 4
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.7795098019817145
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 9600
# 	RUN DURATION: 0.23836231231689453s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.7761477994214032
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 9520
# 	RUN DURATION: 0.23836326599121094s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.7305541734512079
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 8480
# 	RUN DURATION: 0.21043729782104492s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.7319558352714018
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 9360
# 	RUN DURATION: 0.2343730926513672s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.7232687489533169
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 7440
# 	RUN DURATION: 0.18849611282348633s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.7265262838582223
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 8080
# 	RUN DURATION: 0.204453706741333s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.715758760376648
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 7440
# 	RUN DURATION: 0.19150948524475098s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.7120335660845177
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 9040
# 	RUN DURATION: 0.22537589073181152s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.6878491980183383
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 6080
# 	RUN DURATION: 0.14959979057312012s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.7382996653032456
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 9280
# 	RUN DURATION: 0.23337626457214355s
# Num_points: 4 Solved Reliable
# Num points: 5
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.5860318924426245
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 32900
# 	RUN DURATION: 1.0083041191101074s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.5989123913783927
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 43900
# 	RUN DURATION: 1.3454248905181885s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.5967889249213806
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 41600
# 	RUN DURATION: 1.2596321105957031s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.5941128024841389
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 46500
# 	RUN DURATION: 1.419205904006958s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.5715604822373015
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 21900
# 	RUN DURATION: 0.6632266044616699s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.5927790097459371
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 39300
# 	RUN DURATION: 1.1938085556030273s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.5991241971044912
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 42200
# 	RUN DURATION: 1.2795794010162354s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.589957537165203
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 33200
# 	RUN DURATION: 1.0073168277740479s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.5915327212203167
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 38500
# 	RUN DURATION: 1.1678681373596191s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.5930650641089591
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 39700
# 	RUN DURATION: 1.2038030624389648s
# Num_points: 5 Solved Reliable
# Num points: 6
# RUN #1
# Maximum number of evaluations
# 	AVG_OBJ:  0.5868746610762197
# 	BEST_OBJ: 0.6008711291510695
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 187.38404393196106s
# RUN #2
# Maximum number of evaluations
# 	AVG_OBJ:  0.5844075194228074
# 	BEST_OBJ: 0.6008910048951168
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 187.62340378761292s
# RUN #3
# Maximum number of evaluations
# 	AVG_OBJ:  0.5833729129558293
# 	BEST_OBJ: 0.6007836407735274
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 187.45186281204224s
# RUN #4
# Maximum number of evaluations
# 	AVG_OBJ:  0.5850117196109037
# 	BEST_OBJ: 0.6001177135898503
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 187.60446310043335s
# RUN #5
# Maximum number of evaluations
# 	AVG_OBJ:  0.5879716533367393
# 	BEST_OBJ: 0.6007260998643394
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 187.3491289615631s
# RUN #6
# Maximum number of evaluations
# 	AVG_OBJ:  0.5863411800637045
# 	BEST_OBJ: 0.600697458775302
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 187.32320713996887s
# RUN #7
# Maximum number of evaluations
# 	AVG_OBJ:  0.585730040464062
# 	BEST_OBJ: 0.600859073320483
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 187.41595816612244s
# RUN #8
# Maximum number of evaluations
# 	AVG_OBJ:  0.5853601251139907
# 	BEST_OBJ: 0.6005820642038541
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 187.29228973388672s
# RUN #9
# Maximum number of evaluations
# 	AVG_OBJ:  0.5817519338257202
# 	BEST_OBJ: 0.6005980367649507
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 187.8507959842682s
# RUN #10
# Maximum number of evaluations
# 	AVG_OBJ:  0.5835408035147985
# 	BEST_OBJ: 0.6007517053820377
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 187.771009683609s
# Num points: 7
# RUN #1
# Maximum number of evaluations
# 	AVG_OBJ:  0.5120259214698247
# 	BEST_OBJ: 0.5325006476671924
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 227.94760036468506s
# RUN #2
# Maximum number of evaluations
# 	AVG_OBJ:  0.5138118318587046
# 	BEST_OBJ: 0.5333050939187844
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 229.0825662612915s
# RUN #3
# Maximum number of evaluations
# 	AVG_OBJ:  0.5140854651699357
# 	BEST_OBJ: 0.5314410011386497
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 229.01973462104797s
# RUN #4
# Maximum number of evaluations
# 	AVG_OBJ:  0.5135443847901688
# 	BEST_OBJ: 0.5338341053460164
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 228.01940894126892s
# RUN #5
# Maximum number of evaluations
# 	AVG_OBJ:  0.512859518203545
# 	BEST_OBJ: 0.5329058190019278
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 228.98283219337463s
# RUN #6
# Maximum number of evaluations
# 	AVG_OBJ:  0.5118308836517125
# 	BEST_OBJ: 0.5326134427093164
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 227.83789443969727s
# RUN #7
# Maximum number of evaluations
# 	AVG_OBJ:  0.5134332332891475
# 	BEST_OBJ: 0.5331082963880353
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 228.42532348632812s
# RUN #8
# Maximum number of evaluations
# 	AVG_OBJ:  0.5135259412116254
# 	BEST_OBJ: 0.5340267500578932
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 228.27073669433594s
# RUN #9
# Maximum number of evaluations
# 	AVG_OBJ:  0.5139785383905062
# 	BEST_OBJ: 0.5349377397020726
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 229.14340376853943s
# RUN #10
# Maximum number of evaluations
# 	AVG_OBJ:  0.512022272406614
# 	BEST_OBJ: 0.5346685377695761
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 228.5888864994049s
# Num points: 8
# RUN #1
# Maximum number of evaluations
# 	AVG_OBJ:  0.4820069000571891
# 	BEST_OBJ: 0.5171522897485028
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 273.77807688713074s
# RUN #2
# Maximum number of evaluations
# 	AVG_OBJ:  0.48488530648782185
# 	BEST_OBJ: 0.5156628829552101
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 273.3462312221527s
# RUN #3
# Maximum number of evaluations
# 	AVG_OBJ:  0.4859750674779478
# 	BEST_OBJ: 0.5130159122293484
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 272.62216663360596s
# RUN #4
# Maximum number of evaluations
# 	AVG_OBJ:  0.48866588671901623
# 	BEST_OBJ: 0.5140864606603663
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 272.9961669445038s
# RUN #5
# Maximum number of evaluations
# 	AVG_OBJ:  0.4882041345005523
# 	BEST_OBJ: 0.5165444177190043
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 272.6161832809448s
# RUN #6
# Maximum number of evaluations
# 	AVG_OBJ:  0.48726572768520765
# 	BEST_OBJ: 0.5170765668954557
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 273.4320013523102s
# RUN #7
# Maximum number of evaluations
# 	AVG_OBJ:  0.4826744155801336
# 	BEST_OBJ: 0.5166768600554469
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 269.90658593177795s
# RUN #8
# Maximum number of evaluations
# 	AVG_OBJ:  0.4863941657829562
# 	BEST_OBJ: 0.5173380996152723
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 269.90745210647583s
# RUN #9
# Maximum number of evaluations
# 	AVG_OBJ:  0.4849561405926107
# 	BEST_OBJ: 0.5153882032022076
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 268.49517273902893s
# RUN #10
# Maximum number of evaluations
# 	AVG_OBJ:  0.4869381551153692
# 	BEST_OBJ: 0.5167820299960469
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 268.2707998752594s
# Num points: 9
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.41567606735472695
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 1718280
# 	RUN DURATION: 107.06676530838013s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.4153508061862782
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 1637100
# 	RUN DURATION: 102.7183837890625s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.41542416690674167
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 1575180
# 	RUN DURATION: 98.25232982635498s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.4219947095080306
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 2059560
# 	RUN DURATION: 128.77373385429382s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.42151732750720833
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 2255400
# 	RUN DURATION: 140.82748651504517s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.4217011365113231
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 2999520
# 	RUN DURATION: 188.5021469593048s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.41036944146831456
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 1031940
# 	RUN DURATION: 64.61338520050049s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.41654978220935485
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 2123100
# 	RUN DURATION: 132.68134903907776s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.4238919800376772
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 3068460
# 	RUN DURATION: 192.9043607711792s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.42329216215981674
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 4042620
# 	RUN DURATION: 254.09074544906616s
# Num_points: 9 Solved Reliable

# %%
DIR = "Baseline/"
FILENAME = f"num_points_{num_points}_{optimum_accuracy}_base"

# %%
save_reliable_results(f"{DIR}{FILENAME}.csv", num_points_list, results, x_name="num_points")
# Out:
# Exitflag -3, Filtered 1945740
# Exitflag -3, Filtered 2797560
# Exitflag -3, Filtered 2556300
# Exitflag -3, Filtered 3776940
# Exitflag -3, Filtered 2480580
# Exitflag -3, Filtered 3434460
# Exitflag -3, Filtered 2566620
# Exitflag -3, Filtered 2216400
# Exitflag -3, Filtered 1945740
# Exitflag -3, Filtered 2797560
# Exitflag -3, Filtered 2556300
# Exitflag -3, Filtered 3776940
# Exitflag -3, Filtered 2480580
# Exitflag -3, Filtered 3434460
# Exitflag -3, Filtered 2566620
# Exitflag -3, Filtered 2216400

# %%
save_pickle(f"{DIR}{FILENAME}.pickle", results)
# Out:
# Saved object
