# %%
import matplotlib.pyplot as plt
from math import sqrt
from time import sleep, time
from random import seed

from DE import DifferentialEvolution
from Packomania import Packomania
from utils import *

# %%
seed(0)
num_points_list = [2,3,4,5,6,7,8,9]
differential_weight = 0.5               
crossover_prob = 0.3
max_evaluations = 5e6
optimum_accuracy = 1e-3


results = []
for num_points in num_points_list:
    print("Num points: {}".format(num_points))
    dim = num_points*2
    
    popsize = 10*dim
    bounds = [[0, 1] for i in range(num_points*2)]
    pk = Packomania(num_points)
    optimum = pk.distance
    
    de = DifferentialEvolution(
                       scattering_points, 
                       bounds, 
                       popsize, 
                       differential_weight, 
                       crossover_prob
    )
    de.set_optimum(optimum, optimum_accuracy)
    failed, r = find_reliable(algo=de,
                            stop_on_fail=False,
                            max_evaluations=max_evaluations)
    results.append(r)
    if not failed:
        print("Num_points: {} Solved Reliable".format(num_points) )
# Out:
# Num points: 2
# RUN #1
# Optimum reached
# 	AVG_OBJ:  1.1195623998382878
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.009005308151245117s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  1.1266768930576725
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 640
# 	RUN DURATION: 0.008979320526123047s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  1.142313389011121
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.008974790573120117s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  1.0092882809582264
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 360
# 	RUN DURATION: 0.004987478256225586s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  1.1689378761503306
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 520
# 	RUN DURATION: 0.006979465484619141s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  1.1065171040770043
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 520
# 	RUN DURATION: 0.007979154586791992s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  1.1426890297178411
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 520
# 	RUN DURATION: 0.007979869842529297s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  1.0296873122418526
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 320
# 	RUN DURATION: 0.0049855709075927734s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  1.2427433660365765
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 760
# 	RUN DURATION: 0.010973215103149414s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  1.1707435788086424
# 	BEST_OBJ: 1.4142135623730951
# 	EVALUATIONS: 600
# 	RUN DURATION: 0.00993967056274414s
# Num_points: 2 Solved Reliable
# Num points: 3
# RUN #1
# Optimum reached
# 	AVG_OBJ:  1.0233918537704947
# 	BEST_OBJ: 1.0351802858176686
# 	EVALUATIONS: 101340
# 	RUN DURATION: 2.022646188735962s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  1.0185092541299061
# 	BEST_OBJ: 1.0346417673929122
# 	EVALUATIONS: 60240
# 	RUN DURATION: 1.1509504318237305s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  1.0164978116314254
# 	BEST_OBJ: 1.034517911580094
# 	EVALUATIONS: 18600
# 	RUN DURATION: 0.36200571060180664s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  1.0197832102888484
# 	BEST_OBJ: 1.034601365149179
# 	EVALUATIONS: 47280
# 	RUN DURATION: 0.90657639503479s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  1.0207662320744233
# 	BEST_OBJ: 1.035158093485496
# 	EVALUATIONS: 79200
# 	RUN DURATION: 1.4980225563049316s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  1.0215859775045335
# 	BEST_OBJ: 1.0343130290021214
# 	EVALUATIONS: 60720
# 	RUN DURATION: 1.1608963012695312s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.979656066895799
# 	BEST_OBJ: 1.0345796719868676
# 	EVALUATIONS: 4920
# 	RUN DURATION: 0.09474778175354004s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  1.0096293879935587
# 	BEST_OBJ: 1.0347490036888
# 	EVALUATIONS: 10860
# 	RUN DURATION: 0.2094745635986328s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  1.014868561420259
# 	BEST_OBJ: 1.034701796415203
# 	EVALUATIONS: 20220
# 	RUN DURATION: 0.3929481506347656s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.995465218389223
# 	BEST_OBJ: 1.034737290539682
# 	EVALUATIONS: 6540
# 	RUN DURATION: 0.12665939331054688s
# Num_points: 3 Solved Reliable
# Num points: 4
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.6168982788957713
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 4000
# 	RUN DURATION: 0.09677457809448242s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.7630747103551357
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 11280
# 	RUN DURATION: 0.27426815032958984s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.7234526030995947
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 9120
# 	RUN DURATION: 0.22140836715698242s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.7515732561943287
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 9200
# 	RUN DURATION: 0.22340106964111328s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.7216115662864836
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 10000
# 	RUN DURATION: 0.24135351181030273s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.7040434182061398
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 6960
# 	RUN DURATION: 0.16854548454284668s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.7496660788687176
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 9680
# 	RUN DURATION: 0.23437762260437012s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.7317765412929778
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 8480
# 	RUN DURATION: 0.20345520973205566s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.6742152966934765
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 6320
# 	RUN DURATION: 0.15156316757202148s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.7015559776179903
# 	BEST_OBJ: 1.0
# 	EVALUATIONS: 7520
# 	RUN DURATION: 0.18054556846618652s
# Num_points: 4 Solved Reliable
# Num points: 5
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.5883401436518577
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 39800
# 	RUN DURATION: 1.1808431148529053s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.5823853191529945
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 28800
# 	RUN DURATION: 0.8487582206726074s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.5854709443798538
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 31800
# 	RUN DURATION: 0.9414560794830322s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.5912111142052763
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 41600
# 	RUN DURATION: 1.2376902103424072s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.6017105464253224
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 42900
# 	RUN DURATION: 1.267679214477539s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.6064880338848225
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 58100
# 	RUN DURATION: 1.7213973999023438s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.5918226826257885
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 34000
# 	RUN DURATION: 1.0013227462768555s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.593223647688855
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 38400
# 	RUN DURATION: 1.1379578113555908s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.6003980088550381
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 42600
# 	RUN DURATION: 1.2646191120147705s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.6163827376349185
# 	BEST_OBJ: 0.7071067811865476
# 	EVALUATIONS: 83500
# 	RUN DURATION: 2.491339921951294s
# Num_points: 5 Solved Reliable
# Num points: 6
# RUN #1
# Maximum number of evaluations
# 	AVG_OBJ:  0.5858565011820431
# 	BEST_OBJ: 0.5997579547303935
# 	EVALUATIONS: 5000040
# 	RUN DURATION: 190.12976384162903s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.5799283265678586
# 	BEST_OBJ: 0.6000851382998788
# 	EVALUATIONS: 2303880
# 	RUN DURATION: 87.74339818954468s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.5783265095294962
# 	BEST_OBJ: 0.6001156522382461
# 	EVALUATIONS: 1322760
# 	RUN DURATION: 48.748674392700195s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.581778107185961
# 	BEST_OBJ: 0.5999726265635976
# 	EVALUATIONS: 1911240
# 	RUN DURATION: 71.88581895828247s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.572048569149993
# 	BEST_OBJ: 0.6001477158072522
# 	EVALUATIONS: 734880
# 	RUN DURATION: 27.438645362854004s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.5795884945067277
# 	BEST_OBJ: 0.6001729204300821
# 	EVALUATIONS: 968040
# 	RUN DURATION: 36.16431784629822s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.5764980174664392
# 	BEST_OBJ: 0.6002594553992836
# 	EVALUATIONS: 760560
# 	RUN DURATION: 28.55468225479126s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.5732604066053485
# 	BEST_OBJ: 0.6002494972750624
# 	EVALUATIONS: 737280
# 	RUN DURATION: 27.610165119171143s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.5717833056843339
# 	BEST_OBJ: 0.6002864518021596
# 	EVALUATIONS: 522720
# 	RUN DURATION: 19.4819176197052s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.5710239894257086
# 	BEST_OBJ: 0.60061415965077
# 	EVALUATIONS: 720120
# 	RUN DURATION: 26.82328963279724s
# Num points: 7
# RUN #1
# Maximum number of evaluations
# 	AVG_OBJ:  0.5146784462631355
# 	BEST_OBJ: 0.5330936456021964
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 226.23518633842468s
# RUN #2
# Maximum number of evaluations
# 	AVG_OBJ:  0.5119731934251192
# 	BEST_OBJ: 0.5334407102677002
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 227.06595015525818s
# RUN #3
# Maximum number of evaluations
# 	AVG_OBJ:  0.5139254574222665
# 	BEST_OBJ: 0.5311751993972292
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 226.7787184715271s
# RUN #4
# Maximum number of evaluations
# 	AVG_OBJ:  0.5121127143461022
# 	BEST_OBJ: 0.5300958180255261
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 226.26509881019592s
# RUN #5
# Maximum number of evaluations
# 	AVG_OBJ:  0.5129585044680495
# 	BEST_OBJ: 0.5338040923486468
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 227.14175486564636s
# RUN #6
# Maximum number of evaluations
# 	AVG_OBJ:  0.5118211227229351
# 	BEST_OBJ: 0.5302985814854135
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 226.406720161438s
# RUN #7
# Maximum number of evaluations
# 	AVG_OBJ:  0.5114917262965618
# 	BEST_OBJ: 0.5335172895008043
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 227.1636962890625s
# RUN #8
# Maximum number of evaluations
# 	AVG_OBJ:  0.5149763554011484
# 	BEST_OBJ: 0.5337999680588094
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 226.0716154575348s
# RUN #9
# Maximum number of evaluations
# 	AVG_OBJ:  0.5141202959200093
# 	BEST_OBJ: 0.5313932010103496
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 227.11482763290405s
# RUN #10
# Maximum number of evaluations
# 	AVG_OBJ:  0.514277292402608
# 	BEST_OBJ: 0.5327295852492027
# 	EVALUATIONS: 5000100
# 	RUN DURATION: 226.79568004608154s
# Num points: 8
# RUN #1
# Maximum number of evaluations
# 	AVG_OBJ:  0.4915512075756318
# 	BEST_OBJ: 0.5161511939842685
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 271.9320116043091s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.4841541710177113
# 	BEST_OBJ: 0.5166668556513713
# 	EVALUATIONS: 3227360
# 	RUN DURATION: 175.3990957736969s
# RUN #3
# Maximum number of evaluations
# 	AVG_OBJ:  0.4856122197243334
# 	BEST_OBJ: 0.5128403884164433
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 271.76746249198914s
# RUN #4
# Maximum number of evaluations
# 	AVG_OBJ:  0.4877861863193692
# 	BEST_OBJ: 0.5148197233486839
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 272.05266785621643s
# RUN #5
# Maximum number of evaluations
# 	AVG_OBJ:  0.48543724708173225
# 	BEST_OBJ: 0.5139303077990375
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 271.79836869239807s
# RUN #6
# Maximum number of evaluations
# 	AVG_OBJ:  0.48592015520195053
# 	BEST_OBJ: 0.5157187171709983
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 271.4991817474365s
# RUN #7
# Maximum number of evaluations
# 	AVG_OBJ:  0.4865732578759719
# 	BEST_OBJ: 0.5114672838739192
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 272.690970659256s
# RUN #8
# Maximum number of evaluations
# 	AVG_OBJ:  0.4837450448639121
# 	BEST_OBJ: 0.5141200365479881
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 272.1713721752167s
# RUN #9
# Maximum number of evaluations
# 	AVG_OBJ:  0.48636106549264657
# 	BEST_OBJ: 0.5153882032022076
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 271.96991086006165s
# RUN #10
# Maximum number of evaluations
# 	AVG_OBJ:  0.4846103717311515
# 	BEST_OBJ: 0.5154782771925592
# 	EVALUATIONS: 5000000
# 	RUN DURATION: 271.41539311408997s
# Num points: 9
# RUN #1
# Optimum reached
# 	AVG_OBJ:  0.4111574565666418
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 1174140
# 	RUN DURATION: 73.95728039741516s
# RUN #2
# Optimum reached
# 	AVG_OBJ:  0.41136886732658
# 	BEST_OBJ: 0.49924165779934654
# 	EVALUATIONS: 1290240
# 	RUN DURATION: 81.62079334259033s
# RUN #3
# Optimum reached
# 	AVG_OBJ:  0.4190478863030523
# 	BEST_OBJ: 0.499120070931921
# 	EVALUATIONS: 1760940
# 	RUN DURATION: 111.7761754989624s
# RUN #4
# Optimum reached
# 	AVG_OBJ:  0.40973181385473034
# 	BEST_OBJ: 0.4999336443826337
# 	EVALUATIONS: 1293660
# 	RUN DURATION: 81.69060707092285s
# RUN #5
# Optimum reached
# 	AVG_OBJ:  0.41376651159337885
# 	BEST_OBJ: 0.4991264121590411
# 	EVALUATIONS: 1682100
# 	RUN DURATION: 106.4344573020935s
# RUN #6
# Optimum reached
# 	AVG_OBJ:  0.4209474767165794
# 	BEST_OBJ: 0.4991597041498457
# 	EVALUATIONS: 2255040
# 	RUN DURATION: 142.7324149608612s
# RUN #7
# Optimum reached
# 	AVG_OBJ:  0.42250549931691556
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 2815740
# 	RUN DURATION: 178.71023321151733s
# RUN #8
# Optimum reached
# 	AVG_OBJ:  0.416024106528467
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 1906380
# 	RUN DURATION: 120.86886668205261s
# RUN #9
# Optimum reached
# 	AVG_OBJ:  0.41582975094988117
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 1914120
# 	RUN DURATION: 121.67072296142578s
# RUN #10
# Optimum reached
# 	AVG_OBJ:  0.4214536832548098
# 	BEST_OBJ: 0.5
# 	EVALUATIONS: 3416220
# 	RUN DURATION: 216.6039273738861s
# Num_points: 9 Solved Reliable

# %%
DIR = "Baseline/"
FILENAME = f"base_{optimum_accuracy}"

# %%
save_reliable_results(f"{DIR}{FILENAME}.csv", num_points_list, results, x_name="num_points")

# %%
save_pickle(f"{DIR}{FILENAME}.pickle", results)
# Out:
# Saved object
